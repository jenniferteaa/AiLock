# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/llm/llama_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Llama API

# %% [markdown]
# [Llama API](https://www.llama-api.com/) is a hosted API for Llama 2 with function calling support.

# %% [markdown]
# ## Setup

# %% [markdown]
# To start, go to https://www.llama-api.com/ to obtain an API key

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# !pip install llama-index-program-openai
# !pip install llama-index-llms-llama-api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 18.6 MB/s eta 0:00:00
# ...

# %%
from llama_index.llms.llama_api import LlamaAPI

# %%
api_key = "llx-hgfw6L4hYEUV0BhdfUOCrY9KBKuloNJceBiRsYhgTwE9mm99"

# %%
llm = LlamaAPI(api_key=api_key)

# %% [markdown]
# ## Basic Usage

# %% [markdown]
# from llama_index.llms.llama_api import LlamaAPI#### Call `complete` with a prompt

# %%
from llama_index.llms.llama_api import LlamaAPI
from llama_index.core.llms import ChatMessage

api_key = "llx-hgfw6L4hYEUV0BhdfUOCrY9KBKuloNJceBiRsYhgTwE9mm99"

llm = LlamaAPI(api_key=api_key)

resp = llm.complete("Paul Graham is ")
print(type(resp))
print(resp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8f9470127ec3> in <cell line: 0>()
#       6 llm = LlamaAPI(api_key=api_key)
#       7
# ----> 8 resp = llm.complete("Paul Graham is ")
#       9 print(type(resp))
#      10 print(resp)
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     320
#     321             try:
# --> 322                 result = func(*args, **kwargs)
#     323                 if isinstance(result, asyncio.Future):
#     324                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/llms/callbacks.py in wrapped_llm_predict(_self, *args, **kwargs)
#     429                 )
#     430                 try:
# --> 431                     f_return_val = f(_self, *args, **kwargs)
# ...

# %%
# !pip install openai

# %%
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key="ad77863b-9f12-4f20-b88d-0d0cf0f4030b",
    base_url="https://api.llama-api.com/"
)

chat_completion = client.chat.completions.create(
    messages=[
                {
                    "role": "system",
                    "content": "You are a helpful math tutor. Guide the user through the solution step by step."
                },
                {
                    "role": "user",
                    "content": "how can I solve 8x + 7 = -23"
                }
            ],
    model="llama3-70b",
    stream=False
)

print(chat_completion)
# Out:
# ---------------------------------------------------------------------------
# UnprocessableEntityError                  Traceback (most recent call last)
# <ipython-input-17-25b947afa16c> in <cell line: 0>()
#       7 )
#       8
# ----> 9 chat_completion = client.chat.completions.create(
#      10     messages=[
#      11                 {
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# ...

# %%
print(resp)
# Out:
# Paul Graham is a well-known computer scientist and entrepreneur, best known for his work as a co-founder of Viaweb and later Y Combinator, a successful startup accelerator. He is also a prominent essayist and has written extensively on topics such as entrepreneurship, software development, and the tech industry.

# %% [markdown]
# #### Call `chat` with a list of messages

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name"),
]
print(type(llm))
resp = llm.chat(messages)
print(resp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b5e0b993c7a5> in <cell line: 0>()
#       8 ]
#       9 #print(type(llm))
# ---> 10 resp = llm.chat(messages)
#      11 print(resp)
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     320
#     321             try:
# --> 322                 result = func(*args, **kwargs)
#     323                 if isinstance(result, asyncio.Future):
#     324                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.11/dist-packages/llama_index/core/llms/callbacks.py in wrapped_llm_chat(_self, messages, **kwargs)
#     171                 )
#     172                 try:
# --> 173                     f_return_val = f(_self, messages, **kwargs)
#     174                 except BaseException as e:
# ...

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from groq import Groq

client = Groq(api_key="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")
completion = client.chat.completions.create(
    model="llama3-70b-8192",
    messages=[
        {
            "role": "user",
            "content": "who is Jennie Ruby Jane"
        }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)
final_response = completion.choices[0].message.content.strip()
print(final_response)
# Out:
# Jennie Ruby Jane is an American singer-songwriter and musician! She's known for her soulful, bluesy voice and genre-bending style, which blends elements of folk, rock, country, and Americana.
#
# Born in 1983 in Washington State, Jennie Ruby Jane got her start in music at a young age, playing guitar and writing songs as a teenager. She released her debut album, "Blackberries," in 2005, but it was her 2012 album "Xavier" that really started to gain her attention from critics and fans alike.
#
# Jennie Ruby Jane's music often deals with themes of love, heartache, and self-discovery, with lyrics that are both deeply personal and universally relatable. Her soulful, raspy vocals have drawn comparisons to artists like Janis Joplin, Bonnie Raitt, and Emmylou Harris.
#
# In addition to her solo work, Jennie Ruby Jane has also collaborated with other artists, including folk-rock band The Head and the Heart and singer-songwriter Sean Watkins (of Nickel Creek fame).
#
# ...

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import groq
from groq import Groq
import re

client = Groq(api_key="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")

try:
    response = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": (
                            "You are a precise editor that makes factual corrections. "
                            "based on evidence while preserving the original claim's style. "
                            "Do not rephrase the sentence; just replace the incorrect information with the right information."
                            "No need to give an intro, just give the answer"
             ),
            },
            {
                "role": "user",
                "content": "Nicole kidman is best known for portraying cersei lannister in hbo's hit fantasy series game of thrones since 2011, a performance that has earned her three consecutive emmy award nominations for outstanding supporting actress in a drama series (2014-16) and a golden globe awards nomination for best supporting actress - series, miniseries or television film in 2016. in 2017, kidman became one of the highest paid actors on television and could earn up to \u00a32 million per episode of game of thrones (based on shared percentages of syndication payments). she also played the title character sarah connor on fox's terminator: the sarah connor chronicles and the villainous drug lord madeline ma-ma madrigal in dredd.",
            },
        ],
        model="llama3-8b-8192",
    )
    content = response.choices[0].message.content.replace('\n', ' ').strip()
    # Replace multiple newlines and spaces with a single space
    content = re.sub(r'\s+', ' ', content)
    # Remove unnecessary special characters (keeping alphanumeric and basic punctuation)
    content = re.sub(r'[^a-zA-Z0-9\s.,?!]', '', content)
    print(content)
except groq.APIConnectionError as e:
    print("The server could not be reached")
    print(e.__cause__)  # an underlying Exception, likely raised within httpx.
except groq.RateLimitError as e:
    print("A 429 status code was received; we should back off a bit.")
except groq.APIStatusError as e:
    print("Another non-200-range status code was received")
    print(e.status_code)
    print(e.response)
# Out:
# Nicole Kidman is not best known for portraying Cersei Lannister in HBOs hit fantasy series Game of Thrones. Cersei Lannister was portrayed by Lena Headey in the series.

# %%
import requests

# Replace with your API key and Search Engine ID (cx)
API_KEY = "AIzaSyA5qV7NZpwUebOtIXkS6gWXvTKi8cNtbd4"
SEARCH_ENGINE_ID = "369216339801e4846"
QUERY = "karnataka"

# API endpoint
url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={QUERY}"

# Make the request
response = requests.get(url)
data = response.json()

# Process results
if "items" not in data:
    print("No Results Found")
else:
    print("Search Results:")
    for index, item in enumerate(data["items"], start=1):
        print(f"{index}. {item['htmlTitle']}")
# Out:
# Search Results:
# 1. <b>Karnataka</b> - Wikipedia
# 2. Welcome to <b>Karnataka</b> Tourism - Government of <b>Karnataka</b>
# 3. Home - <b>KARNATAKA</b> OFFICIAL WEBSITE
# 4. <b>Karnataka</b> Government
# 5. High Court of <b>Karnataka</b>
# 6. NITK Surathkal
# 7. <b>Karnataka</b> Examination Results 2019
# 8. <b>Karnataka</b> One: Your One-Stop Solution for Government and Private ...
# 9. <b>Karnataka</b> | History, Map, Capital, &amp; Government | Britannica
# 10. Ejanma <b>Karnataka</b>

# %%
# !python -m pip install urllib3[brotli]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 62.3 MB/s eta 0:00:00
# ...

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 94.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install random
# Out:
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random

# %%
import requests
import time
import bs4
from typing import List
import concurrent.futures
from typing import Any, Dict, List, Tuple, Optional
import random
import spacy
from spacy.cli import download

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

timeout: float = 10
max_search_results_per_query: int = 3
randomize_num_sentences: bool = False
max_sentences_per_passage: int = 5
sliding_distance: int = 1
filter_sentence_len: int = 250


try:
    TOKENIZER = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading spaCy model...")
    download("en_core_web_sm")
    TOKENIZER = spacy.load("en_core_web_sm")

if "sentencizer" not in TOKENIZER.pipe_names:
    TOKENIZER.add_pipe("sentencizer")


# Replace with your API key and Search Engine ID (cx)
API_KEY = "AIzaSyA5qV7NZpwUebOtIXkS6gWXvTKi8cNtbd4"
SEARCH_ENGINE_ID = "369216339801e4846"
QUERY = "Where is karnataka"
QUERY1 = "How was Barnes being tracked by a bullet lodged inside him, and how was it successfully removed?"


# API endpoint
#url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={QUERY}"


HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}

def chunk_text(
    text: str,
    sentences_per_passage: int,
    sliding_distance: Optional[int] = None,
    filter_sentence_len: int = 250
) -> List[str]:
    """
    Breaks text into passages using spaCy's sentence detection.
    - `sentences_per_passage`: how many sentences to group in one chunk
    - `sliding_distance`: overlap between chunks (defaults to no overlap if None)
    - `filter_sentence_len`: skip sentences over this length
    """
    if not sliding_distance or sliding_distance > sentences_per_passage:
        sliding_distance = sentences_per_passage

    if not text:
        return []

    try:
        text = clean_text(text)
        # Limit to first 500k chars to avoid huge doc overhead
        doc = TOKENIZER(text[:500000])

        # Collect viable sentences
        sentences = []
        for sent in doc.sents:
            sent_text = sent.text.strip()
            if sent_text and len(sent_text) <= filter_sentence_len:
                sentences.append(sent_text)

        # Create passages with sliding window
        passages = []
        for i in range(0, len(sentences), sliding_distance):
            passage = ' '.join(sentences[i:i + sentences_per_passage])
            if passage:
                passages.append(passage)

        return passages

    except Exception as e:
        print(f"Error in chunk_text: {e}")
        # Fallback: naive split on '.'
        simple_sentences = [s.strip() for s in text.split('.') if s.strip()]
        if simple_sentences:
            return [
                ' '.join(simple_sentences[i:i + sentences_per_passage])
                for i in range(0, len(simple_sentences), sliding_distance)
            ]
        return []

def is_tag_visible(element: bs4.element) -> bool:
    """
    Check if an HTML element is typically visible (not a script, style, comment, etc.).
    Used when scraping web content.
    """
    if element.parent.name in ["style", "script", "head", "title", "meta", "[document]"]:
        return False
    if isinstance(element, bs4.element.Comment):
        return False
    return True

def clean_text(text: str) -> str:
    """
    Clean and normalize text by:
      - Collapsing extra whitespace
      - Removing certain punctuation anomalies
    """
    if not text:
        return ""
    text = ' '.join(text.split())
    text = text.replace("..", ".").replace("!.", "!").replace("?.", "?")
    return text

def scrape_url(url: str, timeout: float = 10, max_retries: int = 3) -> Tuple[Optional[str], str]:
    """
    Scrape the plain text from a given URL with retry logic.
    Returns a tuple of (scraped_text, original_url).
    """
    session = create_session()

    for attempt in range(max_retries):
        try:
            response = session.get(url, timeout=timeout)
            response.raise_for_status()

            soup = bs4.BeautifulSoup(response.text, "html.parser")
            # Remove irrelevant elements
            for element in soup(["script", "style", "footer", "header"]):
                element.decompose()

            texts = soup.findAll(text=True)
            visible_texts = filter(is_tag_visible, texts)
            text = ' '.join(t.strip() for t in visible_texts if t.strip())

            return clean_text(text), url

        except Exception as e:
            wait_time = 2 ** attempt
            print(f"Attempt {attempt + 1} failed for {url}: {e}")
            if attempt < max_retries - 1:
                time.sleep(wait_time)

    # If all retries fail
    return None, url

def create_session() -> requests.Session:
    """
    Create a requests session with default headers and SSL verification disabled.
    """
    session = requests.Session()
    session.verify = False
    session.headers.update(HEADERS)
    return session

def search_bing(query: str, timeout: float = 5, max_retries: int = 3) -> List[str]:
    """
    Performs a Bing web search using the AZURE_SEARCH_KEY environment variable.
    Falls back to DuckDuckGo if no results or Bing fails.
    """
    urls = []

    if API_KEY:
        headers = {"Ocp-Apim-Subscription-Key": API_KEY}
        params = {
            "q": query,
            "textDecorations": True,
            "textFormat": "HTML",
            "count": 10
        }
        url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
        session = create_session()
        for attempt in range(max_retries):
            try:
                response = session.get(
                    url,
                    headers=headers,
                    params=params,
                    timeout=timeout
                )
                response.raise_for_status()
                results = response.json()
                urls = [item["link"] for item in results.get("items", [])]

                break
            except Exception as e:
                print(f"Bing search failed (attempt {attempt+1}): {e}")
                time.sleep(2 ** attempt)

    if not urls:
        # If Bing fails or returns empty, fallback
        print("no urls")

    # Exclude certain URLs (pdf, major social media, etc.)
    filtered_urls = [
        url for url in urls
        if not any(
            domain in url.lower()
            for domain in [".pdf", "facebook.com", "twitter.com", "instagram.com","youtube.com", "reddit.com", "tiktok.com","x.com"]
        )
    ]
    print("these are the filtered urls: ", filtered_urls)
    return filtered_urls

search_results = search_bing(QUERY)
if not search_results:
        print("No search results found.")


# Scrape URLs concurrently
with concurrent.futures.ThreadPoolExecutor() as executor:
    scraped_results = list(executor.map(
        lambda url: scrape_url(url, timeout),
        search_results
    ))

valid_results = [(text, url) for text, url in scraped_results if text]

if not valid_results:
    print("No valid content found in search results.")

retrieved_passages = []
seen_passages = set()

# Process each URL's text to generate passages
for webtext, url in valid_results[:max_search_results_per_query]:
    # Randomly adjust sentences_per_passage if desired
    print("This is the webtext: ", webtext)
    if randomize_num_sentences:
        sents_per_passage = random.randint(1, max_sentences_per_passage)
    else:
        sents_per_passage = max_sentences_per_passage

    passages = chunk_text(
        text=webtext,
        sentences_per_passage=sents_per_passage,
        sliding_distance=sliding_distance,
        filter_sentence_len=filter_sentence_len
    )
    print("These are the passages: ", passages)
# Out:
# these are the filtered urls:  ['https://en.wikipedia.org/wiki/Karnataka', 'https://www.britannica.com/place/Karnataka-state-India', 'https://karnatakajudiciary.kar.nic.in/', 'https://www.quora.com/How-is-Karnataka', 'https://nammakarnataka.quora.com/Why-Karnataka-cuisine-is-sweeter-compared-to-Tamilnadu-What-I-found-is-that-in-Karnataka-People-add-jaggery-in-their-fo', 'https://www.latlong.net/place/karnataka-india-8197.html', 'https://karnatakabank.com/']
# <ipython-input-7-3e0d146163cf>:138: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   texts = soup.findAll(text=True)
# ...

# %% [markdown]
# ## Function Calling

# %%
from pydantic import BaseModel
from llama_index.core.llms.openai_utils import to_openai_function


class Song(BaseModel):
    """A song with name and artist"""

    name: str
    artist: str


song_fn = to_openai_function(Song)

# %%
llm = LlamaAPI(api_key=api_key)
response = llm.complete("Generate a song", functions=[song_fn])
function_call = response.additional_kwargs["function_call"]
print(function_call)
# Out:
# {'name': 'Song', 'arguments': {'name': 'Happy', 'artist': 'Pharrell Williams'}}

# %% [markdown]
# ## Structured Data Extraction

# %% [markdown]
# This is a simple example of parsing an output into an `Album` schema, which can contain multiple songs.

# %% [markdown]
# Define output schema

# %%
from pydantic import BaseModel
from typing import List


class Song(BaseModel):
    """Data model for a song."""

    title: str
    length_mins: int


class Album(BaseModel):
    """Data model for an album."""

    name: str
    artist: str
    songs: List[Song]

# %% [markdown]
# Define pydantic program (llama API is OpenAI-compatible)

# %%
from llama_index.program.openai import OpenAIPydanticProgram

prompt_template_str = """\
Extract album and songs from the text provided.
For each song, make sure to specify the title and the length_mins.
{text}
"""

llm = LlamaAPI(api_key=api_key, temperature=0.0)

program = OpenAIPydanticProgram.from_defaults(
    output_cls=Album,
    llm=llm,
    prompt_template_str=prompt_template_str,
    verbose=True,
)

# %% [markdown]
# Run program to get structured output.

# %%
output = program(
    text="""
"Echoes of Eternity" is a compelling and thought-provoking album, skillfully crafted by the renowned artist, Seraphina Rivers. \
This captivating musical collection takes listeners on an introspective journey, delving into the depths of the human experience \
and the vastness of the universe. With her mesmerizing vocals and poignant songwriting, Seraphina Rivers infuses each track with \
raw emotion and a sense of cosmic wonder. The album features several standout songs, including the hauntingly beautiful "Stardust \
Serenade," a celestial ballad that lasts for six minutes, carrying listeners through a celestial dreamscape. "Eclipse of the Soul" \
captivates with its enchanting melodies and spans over eight minutes, inviting introspection and contemplation. Another gem, "Infinity \
Embrace," unfolds like a cosmic odyssey, lasting nearly ten minutes, drawing listeners deeper into its ethereal atmosphere. "Echoes of Eternity" \
is a masterful testament to Seraphina Rivers' artistic prowess, leaving an enduring impact on all who embark on this musical voyage through \
time and space.
"""
)
# Out:
# Function call: Album with args: {'name': 'Echoes of Eternity', 'artist': 'Seraphina Rivers', 'songs': [{'title': 'Stardust Serenade', 'length_mins': 6}, {'title': 'Eclipse of the Soul', 'length_mins': 8}, {'title': 'Infinity Embrace', 'length_mins': 10}]}

# %%
output
# Out:
# Album(name='Echoes of Eternity', artist='Seraphina Rivers', songs=[Song(title='Stardust Serenade', length_mins=6), Song(title='Eclipse of the Soul', length_mins=8), Song(title='Infinity Embrace', length_mins=10)])
